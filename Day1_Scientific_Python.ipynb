# %% [markdown]
# <a href="https://colab.research.google.com/github/minhasaleem/Deep-Vision-AI-Workshop/blob/main/Day1_Scientific_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.DataFrame({
    'Name': ['Asha','ravi','Neha','Kiran'],
    'Age': [22,25,28,30],
    'Marks': [80,85,90,88]
}, index = [1,2,3,4])

# %%
df
# Out:
#     Name  Age  Marks
# 1   Asha   22     80
# 2   ravi   25     85
# 3   Neha   28     90
# 4  Kiran   30     88

# %%
import pandas as pd

data = {
    'Name': ['Alice','Bob','Charlie'],
    'Age': [25,30,35],
    'Salary': [50000,60000,70000],
    'Departemnt':['IT','HR','IT']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary Departemnt
# 0    Alice   25   50000         IT
# 1      Bob   30   60000         HR
# 2  Charlie   35   70000         IT

# %%
df=pd.read_csv("/content/sales_data_sample.csv",encoding='latin1')

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2818        False            False      False            False  False
# 2819        False            False      False            False  False
# 2820        False            False      False            False  False
# 2821        False            False      False            False  False
# 2822        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  ADDRESSLINE1  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# Length: 2823, dtype: bool

# %%
data=pd.read_csv("/content/annex1.csv")

# %%
data
# Out:
#            Item Code                                     Item Name  \
# 0    102900005115168                              Niushou Shengcai
# 1    102900005115199                             Sichuan Red Cedar
# 2    102900005115625                         Local Xiaomao Cabbage
# 3    102900005115748                                  White Caitai
# 4    102900005115762                                      Amaranth
# ..               ...                                           ...
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code           Category Name
# 0       1011010101  Flower/Leaf Vegetables
# 1       1011010101  Flower/Leaf Vegetables
# ...

# %%
data.describe()
# Out:
#           Item Code  Category Code
# count  2.510000e+02   2.510000e+02
# mean   1.031908e+14   1.011010e+09
# std    1.048400e+12   2.915469e+02
# min    1.029000e+14   1.011010e+09
# 25%    1.029000e+14   1.011010e+09
# 50%    1.029000e+14   1.011011e+09
# 75%    1.029000e+14   1.011011e+09
# max    1.069740e+14   1.011011e+09

# %%
data.shape
# Out:
# (251, 4)

# %%
import pandas as pd
data=pd.read_csv("/content/annex1.csv")

# %%
data['Item Name']
# Out:
# 0                                  Niushou Shengcai
# 1                                 Sichuan Red Cedar
# 2                             Local Xiaomao Cabbage
# 3                                      White Caitai
# 4                                          Amaranth
#                            ...
# 246                      Haixian Mushroom (Bag) (4)
# 247                        Haixian Mushroom (Bunch)
# 248                      Haixian Mushroom (Bag) (3)
# 249    Chinese Caterpillar Fungus Flowers (Box) (2)
# 250                   Hfyg Haixian Mushroom (Bunch)
# Name: Item Name, Length: 251, dtype: object

# %%
import pandas as pd
df=pd.read_csv("/content/sales_data_sample.csv",encoding='latin1')

# %%
df[['POSTALCODE','COUNTRY']]
# Out:
#      POSTALCODE  COUNTRY
# 0         10022      USA
# 1         51100   France
# 2         75508   France
# 3         90003      USA
# 4           NaN      USA
# ...         ...      ...
# 2818      28034    Spain
# 2819      90110  Finland
# 2820      28034    Spain
# 2821      31000   France
# 2822      51003      USA
#
# [2823 rows x 2 columns]

# %%
data[20:]
# Out:
#            Item Code                                     Item Name  \
# 20   102900005116776                                 Local Spinach
# 21   102900005116790                             Yellow Xincai (1)
# 22   102900005116806                                Black Rapeseed
# 23   102900005118572                            Local Shanghaiqing
# 24   102900005118817                                       Spinach
# ..               ...                                           ...
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code           Category Name
# 20      1011010101  Flower/Leaf Vegetables
# 21      1011010101  Flower/Leaf Vegetables
# ...

# %%
data[20:25]
# Out:
#           Item Code           Item Name  Category Code           Category Name
# 20  102900005116776       Local Spinach     1011010101  Flower/Leaf Vegetables
# 21  102900005116790   Yellow Xincai (1)     1011010101  Flower/Leaf Vegetables
# 22  102900005116806      Black Rapeseed     1011010101  Flower/Leaf Vegetables
# 23  102900005118572  Local Shanghaiqing     1011010101  Flower/Leaf Vegetables
# 24  102900005118817             Spinach     1011010101  Flower/Leaf Vegetables

# %%
df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# USA            1004
# Spain           342
# France          314
# Australia       185
# UK              144
# Italy           113
# Finland          92
# Norway           85
# Singapore        79
# Canada           70
# Denmark          63
# Germany          62
# Sweden           57
# Austria          55
# Japan            52
# Belgium          33
# Switzerland      31
# Philippines      26
# Ireland          16
# Name: count, dtype: int64

# %%
df['COUNTRY'].unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %%
df['COUNTRY'].nunique()
# Out:
# 19

# %%
df['CITY'].value_counts()
# Out:
# CITY
# Madrid         304
# San Rafael     180
# NYC            152
# Singapore       79
# Paris           70
#               ...
# Graz            15
# Munich          14
# Los Angeles     14
# Burbank         13
# Charleroi        8
# Name: count, Length: 73, dtype: int64

# %%
df['CITY'].unique()
# Out:
# array(['NYC', 'Reims', 'Paris', 'Pasadena', 'San Francisco', 'Burlingame',
#        'Lille', 'Bergen', 'Melbourne', 'Newark', 'Bridgewater', 'Nantes',
#        'Cambridge', 'Helsinki', 'Stavern', 'Allentown', 'Salzburg',
#        'Chatswood', 'New Bedford', 'Liverpool', 'Madrid', 'Lule',
#        'Singapore', 'South Brisbane', 'Philadelphia', 'Lyon', 'Vancouver',
#        'Burbank', 'New Haven', 'Minato-ku', 'Torino', 'Boras',
#        'Versailles', 'San Rafael', 'Nashua', 'Brickhaven', 'North Sydney',
#        'Montreal', 'Osaka', 'White Plains', 'Kobenhavn', 'London',
#        'Toulouse', 'Barcelona', 'Los Angeles', 'San Diego', 'Bruxelles',
#        'Tsawassen', 'Boston', 'Cowes', 'Oulu', 'San Jose', 'Graz',
#        'Makati City', 'Marseille', 'Koln', 'Gensve', 'Reggio Emilia',
#        'Frankfurt', 'Espoo', 'Dublin', 'Manchester', 'Aaarhus',
#        'Glendale', 'Sevilla', 'Brisbane', 'Strasbourg', 'Las Vegas',
#        'Oslo', 'Bergamo', 'Glen Waverly', 'Munich', 'Charleroi'],
# ...

# %%
df['CITY'].nunique()
# Out:
# 73

# %%
df.loc[0]
# Out:
# ORDERNUMBER                           10107
# QUANTITYORDERED                          30
# PRICEEACH                              95.7
# ORDERLINENUMBER                           2
# SALES                                2871.0
# ORDERDATE                    2/24/2003 0:00
# STATUS                              Shipped
# QTR_ID                                    1
# MONTH_ID                                  2
# YEAR_ID                                2003
# PRODUCTLINE                     Motorcycles
# MSRP                                     95
# PRODUCTCODE                        S10_1678
# CUSTOMERNAME              Land of Toys Inc.
# PHONE                            2125557818
# ADDRESSLINE1        897 Long Airport Avenue
# ADDRESSLINE2                            NaN
# CITY                                    NYC
# STATE                                    NY
# POSTALCODE                            10022
# COUNTRY                                 USA
# ...

# %%
df.loc[25,'ORDERDATE']
# Out:
# '5/13/2005 0:00'

# %%
df.loc[25,['ORDERDATE','COUNTRY']]
# Out:
# ORDERDATE    5/13/2005 0:00
# COUNTRY               Spain
# Name: 25, dtype: object

# %%
df.loc[0:50,'PRICEEACH']
# Out:
# 0      95.70
# 1      81.35
# 2      94.74
# 3      83.26
# 4     100.00
# 5      96.66
# 6      86.13
# 7     100.00
# 8      98.57
# 9     100.00
# 10    100.00
# 11    100.00
# 12    100.00
# 13    100.00
# 14     92.83
# 15    100.00
# 16    100.00
# 17    100.00
# 18     94.74
# 19    100.00
# 20    100.00
# 21     72.55
# 22     34.91
# 23     76.36
# 24    100.00
# 25    100.00
# 26    100.00
# 27    100.00
# 28    100.00
# 29    100.00
# 30    100.00
# 31    100.00
# 32    100.00
# 33    100.00
# 34    100.00
# 35    100.00
# 36    100.00
# 37    100.00
# 38    100.00
# 39    100.00
# 40    100.00
# 41    100.00
# 42    100.00
# 43    100.00
# 44    100.00
# 45    100.00
# 46    100.00
# 47    100.00
# 48    100.00
# 49    100.00
# 50    100.00
# Name: PRICEEACH, dtype: float64

# %%
df.iloc[0:50,2]
# Out:
# 0      95.70
# 1      81.35
# 2      94.74
# 3      83.26
# 4     100.00
# 5      96.66
# 6      86.13
# 7     100.00
# 8      98.57
# 9     100.00
# 10    100.00
# 11    100.00
# 12    100.00
# 13    100.00
# 14     92.83
# 15    100.00
# 16    100.00
# 17    100.00
# 18     94.74
# 19    100.00
# 20    100.00
# 21     72.55
# 22     34.91
# 23     76.36
# 24    100.00
# 25    100.00
# 26    100.00
# 27    100.00
# 28    100.00
# 29    100.00
# 30    100.00
# 31    100.00
# 32    100.00
# 33    100.00
# 34    100.00
# 35    100.00
# 36    100.00
# 37    100.00
# 38    100.00
# 39    100.00
# 40    100.00
# 41    100.00
# 42    100.00
# 43    100.00
# 44    100.00
# 45    100.00
# 46    100.00
# 47    100.00
# 48    100.00
# 49    100.00
# Name: PRICEEACH, dtype: float64

# %%
df.iloc[0:50,[0,3,2]]
# Out:
#     ORDERNUMBER  ORDERLINENUMBER  PRICEEACH
# 0         10107                2      95.70
# 1         10121                5      81.35
# 2         10134                2      94.74
# 3         10145                6      83.26
# 4         10159               14     100.00
# 5         10168                1      96.66
# 6         10180                9      86.13
# 7         10188                1     100.00
# 8         10201                2      98.57
# 9         10211               14     100.00
# 10        10223                1     100.00
# 11        10237                7     100.00
# 12        10251                2     100.00
# 13        10263                2     100.00
# 14        10275                1      92.83
# 15        10285                6     100.00
# 16        10299                9     100.00
# 17        10309                5     100.00
# 18        10318                1      94.74
# 19        10329                1     100.00
# ...

# %%
df.iloc[0:23,[14,17,20]]
# Out:
#                PHONE           CITY    COUNTRY
# 0         2125557818            NYC        USA
# 1         26.47.1555          Reims     France
# 2   +33 1 46 62 7555          Paris     France
# 3         6265557265       Pasadena        USA
# 4         6505551386  San Francisco        USA
# 5         6505556809     Burlingame        USA
# 6         20.16.1555          Lille     France
# 7      +47 2267 3215         Bergen     Norway
# 8         6505555787  San Francisco        USA
# 9     (1) 47.55.6555          Paris     France
# 10      03 9520 4555      Melbourne  Australia
# 11        2125551500            NYC        USA
# 12        2015559350         Newark        USA
# 13        2035552570    Bridgewater        USA
# 14        40.67.8555         Nantes     France
# 15        6175558555      Cambridge        USA
# 16       90-224 8555       Helsinki    Finland
# 17        07-98 9555        Stavern     Norway
# 18        2155551555      Allentown        USA
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.rename(columns={'STATE':'STATE_NAME'},inplace=True)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df('STATE_NAME')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3660/1761355305.py in <cell line: 0>()
# ----> 1 df('STATE_NAME')
#
# TypeError: 'DataFrame' object is not callable

# %%
df['ORDERDATE']
# Out:
# 0        2/24/2003 0:00
# 1         5/7/2003 0:00
# 2         7/1/2003 0:00
# 3        8/25/2003 0:00
# 4       10/10/2003 0:00
#              ...
# 2818     12/2/2004 0:00
# 2819     1/31/2005 0:00
# 2820      3/1/2005 0:00
# 2821     3/28/2005 0:00
# 2822      5/6/2005 0:00
# Name: ORDERDATE, Length: 2823, dtype: object

# %%
df['ORDERDATE']=pd.to_datetime(df['ORDERDATE'])
df['ORDERDATE']
# Out:
# 0      2003-02-24
# 1      2003-05-07
# 2      2003-07-01
# 3      2003-08-25
# 4      2003-10-10
#           ...
# 2818   2004-12-02
# 2819   2005-01-31
# 2820   2005-03-01
# 2821   2005-03-28
# 2822   2005-05-06
# Name: ORDERDATE, Length: 2823, dtype: datetime64[ns]

# %%
df['year']=df['ORDERDATE'].dt.year
df['year']
# Out:
# 0       2003
# 1       2003
# 2       2003
# 3       2003
# 4       2003
#         ...
# 2818    2004
# 2819    2005
# 2820    2005
# 2821    2005
# 2822    2005
# Name: year, Length: 2823, dtype: int32

# %%
df['month']=df['ORDERDATE'].dt.month
df['month']
# Out:
# 0        2
# 1        5
# 2        7
# 3        8
# 4       10
#         ..
# 2818    12
# 2819     1
# 2820     3
# 2821     3
# 2822     5
# Name: month, Length: 2823, dtype: int32

# %%
df['date']=df['ORDERDATE'].dt.date
df['date']
# Out:
# 0       2003-02-24
# 1       2003-05-07
# 2       2003-07-01
# 3       2003-08-25
# 4       2003-10-10
#            ...
# 2818    2004-12-02
# 2819    2005-01-31
# 2820    2005-03-01
# 2821    2005-03-28
# 2822    2005-05-06
# Name: date, Length: 2823, dtype: object

# %%
df['day']=df['ORDERDATE'].dt.day
df['day']
# Out:
# 0       24
# 1        7
# 2        1
# 3       25
# 4       10
#         ..
# 2818     2
# 2819    31
# 2820     1
# 2821    28
# 2822     6
# Name: day, Length: 2823, dtype: int32

# %%
df['PROFIT_EST'] = df['SALES']*0.2
df['PROFIT_EST']
# Out:
# 0        574.200
# 1        553.180
# 2        776.868
# 3        749.340
# 4       1041.054
#           ...
# 2818     448.880
# 2819     795.702
# 2820    1083.514
# 2821     423.232
# 2822     615.888
# Name: PROFIT_EST, Length: 2823, dtype: float64

# %%
df.drop('PROFIT_EST',axis=1,inplace=True)

# %%
df.drop('date',axis=1,inplace=True)

# %%
df['FULL_NAME'] = df['CONTACTFIRSTNAME'] + ' ' + df['CONTACTLASTNAME']
df['FULL_NAME']
# Out:
# 0                Kwai Yu
# 1           Paul Henriot
# 2        Daniel Da Cunha
# 3            Julie Young
# 4            Julie Brown
#               ...
# 2818        Diego Freyre
# 2819    Pirkko Koskitalo
# 2820        Diego Freyre
# 2821      Annette Roulet
# 2822        Juri Yoshido
# Name: FULL_NAME, Length: 2823, dtype: object

# %%
monthly_sales=df.groupby('MONTH_ID')['SALES'].sum()
print(monthly_sales)
# Out:
# MONTH_ID
# 1      785874.44
# 2      810441.90
# 3      754501.39
# 4      669390.96
# 5      923972.56
# 6      454756.78
# 7      514875.97
# 8      659310.57
# 9      584724.27
# 10    1121215.22
# 11    2118885.67
# 12     634679.12
# Name: SALES, dtype: float64

# %%
monthly_sales.plot(kind='line')
# Out:
# <Axes: xlabel='MONTH_ID'>

# %%
monthly_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='MONTH_ID'>

# %%
orders_per_year = df.groupby('YEAR_ID')['ORDERNUMBER'].nunique()
print(orders_per_year )
# Out:
# YEAR_ID
# 2003    104
# 2004    144
# 2005     59
# Name: ORDERNUMBER, dtype: int64

# %%
avg_sales_product = df.groupby('PRODUCTCODE')['SALES'].mean().sort_values(ascending=False)
print(avg_sales_product)
# Out:
# PRODUCTCODE
# S10_1949    6824.036786
# S10_4698    6553.887308
# S12_1108    6484.050769
# S18_1749    5786.837273
# S18_2238    5726.812963
#                ...
# S24_2022    1786.686400
# S24_2972    1722.811852
# S24_2840    1686.981429
# S32_2206    1654.137200
# S24_3969    1508.257273
# Name: SALES, Length: 109, dtype: float64

# %%
df['DEALSIZE'] = df['DEALSIZE'].str.upper()
df['DEALSIZE']
# Out:
# 0        SMALL
# 1        SMALL
# 2       MEDIUM
# 3       MEDIUM
# 4       MEDIUM
#          ...
# 2818     SMALL
# 2819    MEDIUM
# 2820    MEDIUM
# 2821     SMALL
# 2822    MEDIUM
# Name: DEALSIZE, Length: 2823, dtype: object

# %%
df.to_csv('cleaned_data.csv',index=False)

# %%
import pandas as pd
zd=pd.read_csv('/content/Zudio_sales_data.csv')
zd
# Out:
#       Store Country          State        City Category Clothing Type  \
# 0     Zudio   India      Karnataka       Jalna    Women       Dresses
# 1     Zudio   India        Gujarat       Patna     Kids        Skirts
# 2     Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3     Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4     Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...     ...     ...            ...         ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
zd.head()
# Out:
#    Store Country          State      City Category Clothing Type  \
# 0  Zudio   India      Karnataka     Jalna    Women       Dresses
# 1  Zudio   India        Gujarat     Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh   Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal   Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal  Guwahati      Men       Dresses
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      2022-06-04  ...
# 1            48       404562      Owned      2020-12-19  ...
# 2            97       437773     Rented      2023-09-04  ...
# 3            93       431725      Owned      2024-04-11  ...
# 4            51       415370      Owned      2022-05-29  ...
#
#    Security Features Order ID  Order Date     Month Customer ID  \
# 0              Alarm    88240  2024-11-06  November      233084
# 1              Alarm    78145  2024-06-17      June      926472
# ...

# %%
zd.tail()
# Out:
#       Store Country          State        City Category Clothing Type  \
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# 7894            32       431437      Owned      2024-04-24  ...
# 7895            52       424643      Owned      2024-02-03  ...
# 7896            81       412057      Owned      2021-04-11  ...
# 7897            58       405203     Rented      2022-06-17  ...
# 7898            20       429823      Owned      2023-02-08  ...
#
#       Security Features Order ID  Order Date      Month Customer ID  \
# 7894        CCTV, Alarm    39056  2024-09-27  September      591993
# ...

# %%
zd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   object
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
zd.shape
# Out:
# (7899, 28)

# %%
zd.columns
# Out:
# Index(['Store', 'Country', 'State', 'City', 'Category', 'Clothing Type',
#        'Store Number', 'Postal Code', 'Store Type', 'Store Open Date',
#        'Selling Area Size (sq ft)', 'Store Manager', 'Manager ID',
#        'Store Address', 'Contact Information', 'Operating Hours',
#        'Staff Count', 'Parking Availability', 'Security Features', 'Order ID',
#        'Order Date', 'Month', 'Customer ID', 'Customer Name', 'Product ID',
#        'Price', 'Quantity', 'Sales Profit'],
#       dtype='object')

# %%
zd.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   7899.000000    7899.000000                7899.000000  7899.000000
# mean      50.666034  419982.374984                1112.077478    11.504747
# std       29.095274   11695.237817                 193.239371     5.194722
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       25.000000  409841.000000                 950.000000     7.000000
# 50%       51.000000  419988.000000                1100.000000    12.000000
# 75%       76.000000  430258.000000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   7899.000000    7899.000000  7899.000000  7899.000000  7899.000000
# mean   54920.719965  549440.714521   602.069376  1761.113432     4.519433
# ...

# %%
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2818        False            False      False            False  False
# 2819        False            False      False            False  False
# 2820        False            False      False            False  False
# 2821        False            False      False            False  False
# 2822        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  POSTALCODE  COUNTRY  \
# ...

# %%
zd.isnull().sum()
# Out:
# Store                           0
# Country                         0
# State                           0
# City                            0
# Category                        0
# Clothing Type                   0
# Store Number                    0
# Postal Code                     0
# Store Type                      0
# Store Open Date                 0
# Selling Area Size (sq ft)       0
# Store Manager                   0
# Manager ID                      0
# Store Address                   0
# Contact Information             0
# Operating Hours                 0
# Staff Count                     0
# Parking Availability            0
# Security Features            2038
# Order ID                        0
# Order Date                      0
# Month                           0
# Customer ID                     0
# Customer Name                   0
# Product ID                      0
# Price                           0
# Quantity                        0
# ...

# %%
zd.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7894    False
# 7895    False
# 7896    False
# 7897    False
# 7898    False
# Length: 7899, dtype: bool

# %%
zd['Category']
# Out:
# 0       Women
# 1        Kids
# 2         Men
# 3       Women
# 4         Men
#         ...
# 7894     Kids
# 7895     Kids
# 7896     Kids
# 7897      Men
# 7898    Women
# Name: Category, Length: 7899, dtype: object

# %%
zd[['Manager ID','Staff Count']]
# Out:
#      Manager ID  Staff Count
# 0           M77           17
# 1           M89            6
# 2           M71           18
# 3           M40           13
# 4           M24           19
# ...         ...          ...
# 7894        M68           18
# 7895        M16            4
# 7896        M21           20
# 7897        M87            8
# 7898        M80           14
#
# [7899 rows x 2 columns]

# %%
zd[20:]
# Out:
#       Store Country          State          City Category Clothing Type  \
# 20    Zudio   India     Tamil Nadu         Thane     Kids       Dresses
# 21    Zudio   India          Delhi         Patna     Kids       Dresses
# 22    Zudio   India        Gujarat  Chhattisgarh     Kids       Dresses
# 23    Zudio   India    West Bengal        Nashik    Women         Shoes
# 24    Zudio   India      Karnataka         Noida     Kids      Sweaters
# ...     ...     ...            ...           ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh    Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh    Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu          Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi       Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat     Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
zd['State'].value_counts()
# Out:
# State
# Rajasthan        1013
# Uttar Pradesh    1011
# Delhi            1011
# Gujarat           982
# West Bengal       982
# Maharashtra       975
# Karnataka         963
# Tamil Nadu        962
# Name: count, dtype: int64

# %%
zd['State'].unique()
# Out:
# array(['Karnataka', 'Gujarat', 'Uttar Pradesh', 'West Bengal',
#        'Maharashtra', 'Tamil Nadu', 'Rajasthan', 'Delhi'], dtype=object)

# %%
zd['State']
# Out:
# 0           Karnataka
# 1             Gujarat
# 2       Uttar Pradesh
# 3         West Bengal
# 4         West Bengal
#             ...
# 7894    Uttar Pradesh
# 7895    Uttar Pradesh
# 7896       Tamil Nadu
# 7897            Delhi
# 7898          Gujarat
# Name: State, Length: 7899, dtype: object

# %%
zd['State'].nunique()
# Out:
# 8

# %%
zd.loc[0]
# Out:
# Store                                                  Zudio
# Country                                                India
# State                                              Karnataka
# City                                                   Jalna
# Category                                               Women
# Clothing Type                                        Dresses
# Store Number                                              30
# Postal Code                                           411084
# Store Type                                             Owned
# Store Open Date                                   2022-06-04
# Selling Area Size (sq ft)                                950
# Store Manager                                      Lori Hill
# Manager ID                                               M77
# Store Address                PSC 4147, Box 1289 APO AA 19737
# Contact Information                        (014)392-4112x860
# ...

# %%
zd.loc[1,['Quantity']]
# Out:
# Quantity    1
# Name: 1, dtype: object

# %%
zd.loc[25,['Product ID','Customer Name']]
# Out:
# Product ID                   693
# Customer Name    Donna Rodriguez
# Name: 25, dtype: object

# %%
zd.iloc[0:25,5]
# Out:
# 0      Dresses
# 1       Skirts
# 2      Hoodies
# 3      Dresses
# 4      Dresses
# 5      Jackets
# 6      Jackets
# 7         Tops
# 8        Shoes
# 9        Jeans
# 10     Hoodies
# 11     Jackets
# 12       Pants
# 13      Skirts
# 14    Sweaters
# 15     Dresses
# 16       Pants
# 17     Hoodies
# 18    T-shirts
# 19    T-shirts
# 20     Dresses
# 21     Dresses
# 22     Dresses
# 23       Shoes
# 24    Sweaters
# Name: Clothing Type, dtype: object

# %%
zd.iloc[0:25,[2,6,8]]
# Out:
#             State  Store Number Store Type
# 0       Karnataka            30      Owned
# 1         Gujarat            48      Owned
# 2   Uttar Pradesh            97     Rented
# 3     West Bengal            93      Owned
# 4     West Bengal            51      Owned
# 5     West Bengal            71      Owned
# 6     Maharashtra            44     Rented
# 7     West Bengal            74      Owned
# 8       Karnataka            71     Rented
# 9       Karnataka            26     Rented
# 10    Maharashtra            26     Rented
# 11  Uttar Pradesh            90     Rented
# 12    Maharashtra             5     Rented
# 13        Gujarat            74      Owned
# 14     Tamil Nadu            75      Owned
# 15      Rajasthan             4     Rented
# 16    Maharashtra            29      Owned
# 17      Rajasthan            43      Owned
# 18      Rajasthan            23     Rented
# 19      Rajasthan             5     Rented
# 20     Tamil Nadu            31     Rented
# ...

# %%
zd.drop_duplicates(inplace=True)

# %%
zd.rename(columns={'Staff Count':'Count'})
# Out:
#       Store Country          State        City Category Clothing Type  \
# 0     Zudio   India      Karnataka       Jalna    Women       Dresses
# 1     Zudio   India        Gujarat       Patna     Kids        Skirts
# 2     Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3     Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4     Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...     ...     ...            ...         ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
zd['Store Open Date']=pd.to_datetime(zd['Store Open Date'])
zd['Store Open Date']
# Out:
# 0      2022-06-04
# 1      2020-12-19
# 2      2023-09-04
# 3      2024-04-11
# 4      2022-05-29
#           ...
# 7894   2024-04-24
# 7895   2024-02-03
# 7896   2021-04-11
# 7897   2022-06-17
# 7898   2023-02-08
# Name: Store Open Date, Length: 7899, dtype: datetime64[ns]

# %%
zd['year']=zd['Store Open Date'].dt.year
zd['year']
# Out:
# 0       2022
# 1       2020
# 2       2023
# 3       2024
# 4       2022
#         ...
# 7894    2024
# 7895    2024
# 7896    2021
# 7897    2022
# 7898    2023
# Name: year, Length: 7899, dtype: int32

# %%
import pandas as pd
zd=pd.read_csv('/content/Zudio_sales_data.csv')
zd
# Out:
#       Store Country          State        City Category Clothing Type  \
# 0     Zudio   India      Karnataka       Jalna    Women       Dresses
# 1     Zudio   India        Gujarat       Patna     Kids        Skirts
# 2     Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3     Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4     Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...     ...     ...            ...         ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
zd['COST'] = zd['Price'] - 5
zd['COST']
# Out:
# 0       1953
# 1       2073
# 2       1440
# 3       2464
# 4       1100
#         ...
# 7894    2833
# 7895    1809
# 7896    1956
# 7897    1012
# 7898    2768
# Name: COST, Length: 7899, dtype: int64

# %%
zd.drop('COST',axis=1,inplace=True)

# %%
monthly_orders=zd.groupby('Month')['Price'].sum()
print(monthly_orders)
# Out:
# Month
# April        1228644
# August       1293240
# December      149069
# February     1219689
# January      1256901
# July         1217543
# June         1203358
# March        1257225
# May          1262029
# November     1313258
# October      1343307
# September    1166772
# Name: Price, dtype: int64

# %%
monthly_orders.plot(kind='line')
# Out:
# <Axes: xlabel='Month'>

# %%
monthly_orders.plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
avg_sales_profit = zd.groupby('Order ID')['Sales Profit'].mean().sort_values(ascending=False)
print(avg_sales_profit)
# Out:
# Order ID
# 92395    9596.8
# 67212    9590.4
# 54866    9584.0
# 22163    9580.8
# 55718    9574.4
#           ...
# 55603     203.6
# 73860     202.4
# 31560     202.0
# 99049     201.2
# 51464     200.4
# Name: Sales Profit, Length: 7559, dtype: float64

# %%
zd['Parking Availability']
# Out:
# 0       Not Available
# 1       Not Available
# 2       Not Available
# 3       Not Available
# 4       Not Available
#             ...
# 7894    Not Available
# 7895    Not Available
# 7896    Not Available
# 7897    Not Available
# 7898    Not Available
# Name: Parking Availability, Length: 7899, dtype: object

# %%
zd['Parking Availability'] = zd['Parking Availability'].str.upper()
zd['Parking Availability']
# Out:
# 0       NOT AVAILABLE
# 1       NOT AVAILABLE
# 2       NOT AVAILABLE
# 3       NOT AVAILABLE
# 4       NOT AVAILABLE
#             ...
# 7894    NOT AVAILABLE
# 7895    NOT AVAILABLE
# 7896    NOT AVAILABLE
# 7897    NOT AVAILABLE
# 7898    NOT AVAILABLE
# Name: Parking Availability, Length: 7899, dtype: object

# %%
zd.to_csv('Zudio_cleaned_data.csv',index=False)
